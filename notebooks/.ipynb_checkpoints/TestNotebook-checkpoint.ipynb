#  {'date': '2020-12-26', 'count': '11060'},
#  {'date': '2020-12-27', 'count': '12222'},
#  {'date': '2020-12-28', 'count': '8668'},
#  {'date': '2020-12-29', 'count': '10564'},
#  {'date': '2020-12-30', 'count': '12592'},
#  {'date': '2020-12-31', 'count': '14243'},
#  {'date': '2021-01-01', 'count': '14600'},
#  {'date': '2021-01-02', 'count': '10719'},
#  {'date': '2021-01-03', 'count': '12826'},
#  {'date': '2021-01-04', 'count': '10774'},
#  {'date': '2021-01-05', 'count': '12456'},
#  {'date': '2021-01-06', 'count': '15041'},
#  {'date': '2021-01-07', 'count': '16351'},
#  {'date': '2021-01-08', 'count': '17217'},
#  {'date': '2021-01-09', 'count': '16206'},
#  {'date': '2021-01-10', 'count': '13224'},
#  {'date': '2021-01-11', 'count': '12139'},
#  {'date': '2021-01-12', 'count': '14329'},
#  {'date': '2021-01-13', 'count': '14565'},
#  {'date': '2021-01-14', 'count': '15146'},
#  {'date': '2021-01-15', 'count': '13681'},
#  {'date': '2021-01-16', 'count': '15218'},
#  {'date': '2021-01-17', 'count': '14984'},
#  {'date': '2021-01-18', 'count': '14294'},
#  {'date': '2021-01-19', 'count': '18050'},
#  {'date': '2021-01-20', 'count': '16108'},
#  {'date': '2021-01-21', 'count': '19285'},
#  {'date': '2021-01-22', 'count': '18515'},
#  {'date': '2021-01-23', 'count': '17523'},
#  {'date': '2021-01-24', 'count': '14947'},
#  {'date': '2021-01-25', 'count': '16431'},
#  {'date': '2021-01-26', 'count': '15259'},
#  {'date': '2021-01-27', 'count': '19420'},
#  {'date': '2021-01-28', 'count': '18132'},
#  {'date': '2021-01-29', 'count': '16226'},
#  {'date': '2021-01-30', 'count': '14316'},
#  {'date': '2021-01-31', 'count': '13537'},
#  {'date': '2021-02-01', 'count': '12340'},
#  {'date': '2021-02-02', 'count': '13218'},
#  {'date': '2021-02-03', 'count': '14860'},
#  {'date': '2021-02-04', 'count': '12024'},
#  {'date': '2021-02-05', 'count': '14749'}]

# %%
date_pcr =[]
count_pcr =[]
for i in range(0,len(daily_pcr_testing_data)):
    date_pcr.append(daily_pcr_testing_data[i]['date'])
    count_pcr.append(int(daily_pcr_testing_data[i]['count']))

# %%
data_pcr = {'date_pcr':date_pcr,'count_pcr':count_pcr}
data_pcr
# Out:
# {'date_pcr': ['2020-02-18',
#   '2020-02-19',
#   '2020-02-20',
#   '2020-02-21',
#   '2020-02-22',
#   '2020-02-23',
#   '2020-02-24',
#   '2020-02-25',
#   '2020-02-26',
#   '2020-02-27',
#   '2020-02-28',
#   '2020-02-29',
#   '2020-03-01',
#   '2020-03-02',
#   '2020-03-03',
#   '2020-03-04',
#   '2020-03-05',
#   '2020-03-06',
#   '2020-03-07',
#   '2020-03-08',
#   '2020-03-09',
#   '2020-03-10',
#   '2020-03-11',
#   '2020-03-12',
#   '2020-03-13',
#   '2020-03-14',
#   '2020-03-15',
#   '2020-03-16',
#   '2020-03-17',
#   '2020-03-18',
#   '2020-03-19',
#   '2020-03-20',
#   '2020-03-21',
#   '2020-03-22',
#   '2020-03-23',
#   '2020-03-24',
#   '2020-03-25',
#   '2020-03-26',
#   '2020-03-27',
#   '2020-03-28',
#   '2020-03-29',
#   '2020-03-30',
#   '2020-03-31',
#   '2020-04-01',
#   '2020-04-02',
#   '2020-04-03',
#   '2020-04-04',
#   '2020-04-05',
#   '2020-04-06',
#   '2020-04-07',
#   '2020-04-08',
#   '2020-04-09',
#   '2020-04-10',
#   '2020-04-11',
#   '2020-04-12',
#   '2020-04-13',
#   '2020-04-14',
#   '2020-04-15',
#   '2020-04-16',
#   '2020-04-17',
#   '2020-04-18',
#   '2020-04-19',
#   '2020-04-20',
#   '2020-04-21',
#   '2020-04-22',
#   '2020-04-23',
#   '2020-04-24',
#   '2020-04-25',
#   '2020-04-26',
#   '2020-04-27',
#   '2020-04-28',
#   '2020-04-29',
#   '2020-04-30',
#   '2020-05-01',
#   '2020-05-02',
#   '2020-05-03',
#   '2020-05-04',
#   '2020-05-05',
#   '2020-05-06',
#   '2020-05-07',
#   '2020-05-08',
#   '2020-05-09',
#   '2020-05-10',
#   '2020-05-11',
#   '2020-05-12',
#   '2020-05-13',
#   '2020-05-14',
#   '2020-05-15',
#   '2020-05-16',
#   '2020-05-17',
#   '2020-05-18',
#   '2020-05-19',
#   '2020-05-20',
#   '2020-05-21',
#   '2020-05-22',
#   '2020-05-23',
#   '2020-05-24',
#   '2020-05-25',
#   '2020-05-26',
#   '2020-05-27',
#   '2020-05-28',
#   '2020-05-29',
#   '2020-05-30',
#   '2020-05-31',
#   '2020-06-01',
#   '2020-06-02',
#   '2020-06-03',
#   '2020-06-04',
#   '2020-06-05',
#   '2020-06-06',
#   '2020-06-07',
#   '2020-06-08',
#   '2020-06-09',
#   '2020-06-10',
#   '2020-06-11',
#   '2020-06-12',
#   '2020-06-13',
#   '2020-06-14',
#   '2020-06-15',
#   '2020-06-16',
#   '2020-06-17',
#   '2020-06-18',
#   '2020-06-19',
#   '2020-06-20',
#   '2020-06-21',
#   '2020-06-22',
#   '2020-06-23',
#   '2020-06-24',
#   '2020-06-25',
#   '2020-06-26',
#   '2020-06-27',
#   '2020-06-28',
#   '2020-06-29',
#   '2020-06-30',
#   '2020-07-01',
#   '2020-07-02',
#   '2020-07-03',
#   '2020-07-04',
#   '2020-07-05',
#   '2020-07-06',
#   '2020-07-07',
#   '2020-07-08',
#   '2020-07-09',
#   '2020-07-10',
#   '2020-07-11',
#   '2020-07-12',
#   '2020-07-13',
#   '2020-07-14',
#   '2020-07-15',
#   '2020-07-16',
#   '2020-07-17',
#   '2020-07-18',
#   '2020-07-19',
#   '2020-07-20',
#   '2020-07-21',
#   '2020-07-22',
#   '2020-07-23',
#   '2020-07-24',
#   '2020-07-25',
#   '2020-07-26',
#   '2020-07-27',
#   '2020-07-28',
#   '2020-07-29',
#   '2020-07-30',
#   '2020-07-31',
#   '2020-08-01',
#   '2020-08-02',
#   '2020-08-03',
#   '2020-08-04',
#   '2020-08-05',
#   '2020-08-06',
#   '2020-08-07',
#   '2020-08-08',
#   '2020-08-09',
#   '2020-08-10',
#   '2020-08-11',
#   '2020-08-12',
#   '2020-08-13',
#   '2020-08-14',
#   '2020-08-15',
#   '2020-08-16',
#   '2020-08-17',
#   '2020-08-18',
#   '2020-08-19',
#   '2020-08-20',
#   '2020-08-21',
#   '2020-08-22',
#   '2020-08-23',
#   '2020-08-24',
#   '2020-08-25',
#   '2020-08-26',
#   '2020-08-27',
#   '2020-08-28',
#   '2020-08-29',
#   '2020-08-30',
#   '2020-08-31',
#   '2020-09-01',
#   '2020-09-02',
#   '2020-09-03',
#   '2020-09-04',
#   '2020-09-05',
#   '2020-09-06',
#   '2020-09-07',
#   '2020-09-08',
#   '2020-09-09',
#   '2020-09-10',
#   '2020-09-11',
#   '2020-09-12',
#   '2020-09-13',
#   '2020-09-14',
#   '2020-09-15',
#   '2020-09-16',
#   '2020-09-17',
#   '2020-09-18',
#   '2020-09-19',
#   '2020-09-20',
#   '2020-09-21',
#   '2020-09-22',
#   '2020-09-23',
#   '2020-09-24',
#   '2020-09-25',
#   '2020-09-26',
#   '2020-09-27',
#   '2020-09-28',
#   '2020-09-29',
#   '2020-09-30',
#   '2020-10-01',
#   '2020-10-02',
#   '2020-10-03',
#   '2020-10-04',
#   '2020-10-05',
#   '2020-10-06',
#   '2020-10-07',
#   '2020-10-08',
#   '2020-10-09',
#   '2020-10-10',
#   '2020-10-11',
#   '2020-10-12',
#   '2020-10-13',
#   '2020-10-14',
#   '2020-10-15',
#   '2020-10-16',
#   '2020-10-17',
#   '2020-10-18',
#   '2020-10-19',
#   '2020-10-20',
#   '2020-10-21',
#   '2020-10-22',
#   '2020-10-23',
#   '2020-10-24',
#   '2020-10-25',
#   '2020-10-26',
#   '2020-10-27',
#   '2020-10-28',
#   '2020-10-29',
#   '2020-10-30',
#   '2020-10-31',
#   '2020-11-01',
#   '2020-11-02',
#   '2020-11-03',
#   '2020-11-04',
#   '2020-11-05',
#   '2020-11-06',
#   '2020-11-07',
#   '2020-11-08',
#   '2020-11-09',
#   '2020-11-10',
#   '2020-11-11',
#   '2020-11-12',
#   '2020-11-13',
#   '2020-11-14',
#   '2020-11-15',
#   '2020-11-16',
#   '2020-11-17',
#   '2020-11-18',
#   '2020-11-19',
#   '2020-11-20',
#   '2020-11-21',
#   '2020-11-22',
#   '2020-11-23',
#   '2020-11-24',
#   '2020-11-25',
#   '2020-11-26',
#   '2020-11-27',
#   '2020-11-28',
#   '2020-11-29',
#   '2020-11-30',
#   '2020-12-01',
#   '2020-12-02',
#   '2020-12-03',
#   '2020-12-04',
#   '2020-12-05',
#   '2020-12-06',
#   '2020-12-07',
#   '2020-12-08',
#   '2020-12-09',
#   '2020-12-10',
#   '2020-12-11',
#   '2020-12-12',
#   '2020-12-13',
#   '2020-12-14',
#   '2020-12-15',
#   '2020-12-17',
#   '2020-12-16',
#   '2020-12-18',
#   '2020-12-19',
#   '2020-12-20',
#   '2020-12-21',
#   '2020-12-22',
#   '2020-12-23',
#   '2020-12-24',
#   '2020-12-25',
#   '2020-12-26',
#   '2020-12-27',
#   '2020-12-28',
#   '2020-12-29',
#   '2020-12-30',
#   '2020-12-31',
#   '2021-01-01',
#   '2021-01-02',
#   '2021-01-03',
#   '2021-01-04',
#   '2021-01-05',
#   '2021-01-06',
#   '2021-01-07',
#   '2021-01-08',
#   '2021-01-09',
#   '2021-01-10',
#   '2021-01-11',
#   '2021-01-12',
#   '2021-01-13',
#   '2021-01-14',
#   '2021-01-15',
#   '2021-01-16',
#   '2021-01-17',
#   '2021-01-18',
#   '2021-01-19',
#   '2021-01-20',
#   '2021-01-21',
#   '2021-01-22',
#   '2021-01-23',
#   '2021-01-24',
#   '2021-01-25',
#   '2021-01-26',
#   '2021-01-27',
#   '2021-01-28',
#   '2021-01-29',
#   '2021-01-30',
#   '2021-01-31',
#   '2021-02-01',
#   '2021-02-02',
#   '2021-02-03',
#   '2021-02-04',
#   '2021-02-05'],
#  'count_pcr': [1,
#   0,
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   2,
#   5,
#   3,
#   1,
#   10,
#   6,
#   9,
#   1,
#   4,
#   7,
#   3,
#   1,
#   12,
#   10,
#   17,
#   25,
#   88,
#   65,
#   89,
#   151,
#   108,
#   162,
#   119,
#   149,
#   174,
#   143,
#   164,
#   128,
#   131,
#   152,
#   108,
#   136,
#   155,
#   224,
#   219,
#   250,
#   311,
#   295,
#   324,
#   394,
#   353,
#   376,
#   287,
#   397,
#   393,
#   609,
#   431,
#   342,
#   465,
#   548,
#   710,
#   522,
#   702,
#   642,
#   650,
#   774,
#   1141,
#   876,
#   816,
#   1075,
#   1869,
#   1139,
#   1545,
#   1397,
#   1107,
#   1681,
#   1636,
#   1045,
#   1491,
#   1147,
#   1553,
#   1821,
#   1424,
#   1282,
#   1057,
#   1078,
#   889,
#   1489,
#   938,
#   1081,
#   1254,
#   960,
#   1062,
#   1108,
#   1603,
#   1970,
#   1998,
#   1742,
#   1347,
#   1146,
#   1838,
#   1713,
#   1330,
#   1727,
#   1420,
#   1066,
#   1783,
#   2086,
#   1890,
#   1816,
#   1243,
#   1718,
#   1766,
#   1579,
#   1433,
#   1677,
#   1390,
#   1165,
#   1116,
#   1651,
#   1276,
#   1381,
#   1374,
#   1495,
#   827,
#   1181,
#   1134,
#   1232,
#   1349,
#   1243,
#   1439,
#   1607,
#   833,
#   1340,
#   1365,
#   1296,
#   1399,
#   1519,
#   852,
#   599,
#   1290,
#   1610,
#   1182,
#   1424,
#   1749,
#   1341,
#   2251,
#   1310,
#   2288,
#   2470,
#   2406,
#   2723,
#   1888,
#   2184,
#   1924,
#   2158,
#   1700,
#   2012,
#   1811,
#   2018,
#   1851,
#   1126,
#   1349,
#   1403,
#   1683,
#   1600,
#   1864,
#   1540,
#   1712,
#   1395,
#   935,
#   1085,
#   1069,
#   1343,
#   1803,
#   1519,
#   2909,
#   2549,
#   2732,
#   2437,
#   2839,
#   1561,
#   1989,
#   3518,
#   2247,
#   2876,
#   2759,
#   2800,
#   2690,
#   2693,
#   2372,
#   2847,
#   2853,
#   2748,
#   2072,
#   2129,
#   1941,
#   2495,
#   2163,
#   2511,
#   2389,
#   2297,
#   1724,
#   1353,
#   2128,
#   1776,
#   2440,
#   2464,
#   2050,
#   2201,
#   1434,
#   2301,
#   2600,
#   1965,
#   1714,
#   2314,
#   1112,
#   1398,
#   2827,
#   1882,
#   2555,
#   1595,
#   2457,
#   1862,
#   1398,
#   2407,
#   1724,
#   1517,
#   2114,
#   2244,
#   1148,
#   1890,
#   4880,
#   5608,
#   4824,
#   7196,
#   7495,
#   7248,
#   6591,
#   6566,
#   8789,
#   8161,
#   8589,
#   9513,
#   7099,
#   7136,
#   8270,
#   8777,
#   8089,
#   9469,
#   9189,
#   8846,
#   9619,
#   8831,
#   11552,
#   9725,
#   10173,
#   11999,
#   11713,
#   9940,
#   10655,
#   11316,
#   11824,
#   11620,
#   10632,
#   7986,
#   8272,
#   10207,
#   10111,
#   9575,
#   13671,
#   11130,
#   10713,
#   8743,
#   11105,
#   10306,
#   11398,
#   11212,
#   12095,
#   10679,
#   7467,
#   10400,
#   12105,
#   13286,
#   11936,
#   13065,
#   12031,
#   7463,
#   13423,
#   13632,
#   13598,
#   13741,
#   14125,
#   13831,
#   11182,
#   14336,
#   14416,
#   13864,
#   17425,
#   15239,
#   13479,
#   9363,
#   15273,
#   14024,
#   13178,
#   16542,
#   16603,
#   10534,
#   11672,
#   13895,
#   13853,
#   14933,
#   13516,
#   11060,
#   12222,
#   8668,
#   10564,
#   12592,
#   14243,
#   14600,
#   10719,
#   12826,
#   10774,
#   12456,
#   15041,
#   16351,
#   17217,
#   16206,
#   13224,
#   12139,
#   14329,
#   14565,
#   15146,
#   13681,
#   15218,
#   14984,
#   14294,
#   18050,
#   16108,
#   19285,
#   18515,
#   17523,
#   14947,
#   16431,
#   15259,
#   19420,
#   18132,
#   16226,
#   14316,
#   13537,
#   12340,
#   13218,
#   14860,
#   12024,
#   14749]}

# %%
import altair as alt

def pcrtestbarchart(data):     
   
    chart = alt.Chart(data).mark_bar().encode(
        x='x',
        y='y',
    )
    chart_json = chart.to_json()
    #return chart_json
    return chart

data = pd.DataFrame({'x': ['Apple', 'Banana', 'Cars', 'Dogs', 'E'],'y': [25, 30, 6, 7, 2]})
#datas=pd.DataFrame(data_pcr)
pcrtestbarchart(data)
# Out:
# alt.Chart(...)

# %%
import altair as alt

def pcrtestbarchart(data):     
   
    chart = alt.Chart(data).mark_bar().encode(
        x='date_pcr',
        y='count_pcr',
    )
    chart_json = chart.to_json()
    #return chart_json
    return chart

#data = pd.DataFrame({'x': ['Apple', 'Banana', 'Cars', 'Dogs', 'E'],'y': [25, 30, 6, 7, 2]})
datas=pd.DataFrame(data_pcr)
pcrtestbarchart(datas)
# Out:
# alt.Chart(...)

# %%
import sys
print(sys.executable)

# %%
#alt.renderers.enable('default')

# %%
local_active_cases=df.local_active_cases
local_active_cases

# %%
local_deaths = df.local_deaths
local_deaths

# %%
local_recovered =df.local_recovered
local_recovered

# %%
local_total_cases=df.local_total_cases
local_total_cases

# %%
local_new_cases =df.local_new_cases
local_new_cases

# %%
total_pcr_testing_count=df.total_pcr_testing_count
total_pcr_testing_count

# %%
update_date_time =df.update_date_time
update_date_time

# %%
local_total_number_of_individuals_in_hospitals =df.local_total_number_of_individuals_in_hospitals
local_total_number_of_individuals_in_hospitals

# %%
hospital_data = df.hospital_data

# %%
hospital_data

# %%
for i in range (0,len(hospital_data)):
    print("hospital_id:",hospital_data[i]['hospital']['id'])
    print("hospital_name:",hospital_data[i]['hospital']['name'])
    print("cumulative_local:",hospital_data[i]['cumulative_local'])
    print("cumulative_foreign:",hospital_data[i]['cumulative_foreign'])
    print("treatment_local:",hospital_data[i]['treatment_local'])
    print("treatment_foreign:",hospital_data[i]['treatment_foreign'])
    print("created_at:",hospital_data[i]['created_at'])
    print('\n')

# %%
#df_g = pd.read_json("https://api.covid19api.com/summary")

# %%
#df_g = pd.read_json("https://api.covid19api.com/summary").ID

# %%
# to handle  data retrieval
import urllib3
from urllib3 import request# to handle certificate verification
import certifi# to manage json data
import json# for pandas dataframes
import pandas as pd

# %%
from pandas.io.json import json_normalize
#data = json_normalize(data)

# %%
http = urllib3.PoolManager(
       cert_reqs='CERT_REQUIRED',
       ca_certs=certifi.where())

# %%
# get data from the API
url = 'https://api.covid19api.com/summary'
r = http.request('GET', url)
r.status
# Out:
# 200

# %%
data = json.loads(r.data.decode('utf-8'))
data
# Out:
# {'ID': 'd68d0857-b258-494f-9a0f-98c21dd72e17',
#  'Message': '',
#  'Global': {'NewConfirmed': 352684,
#   'TotalConfirmed': 105251877,
#   'NewDeaths': 12401,
#   'TotalDeaths': 2297413,
#   'NewRecovered': 152742,
#   'TotalRecovered': 58566864,
#   'Date': '2021-02-06T15:36:47.049Z'},
#  'Countries': [{'ID': '4ad561f4-1073-4b84-a8f3-3324e37b9a45',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 55265,
#    'NewDeaths': 0,
#    'TotalDeaths': 2407,
#    'NewRecovered': 0,
#    'TotalRecovered': 48018,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8e681788-202e-445c-bd82-3b9d824870af',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 83082,
#    'NewDeaths': 0,
#    'TotalDeaths': 1433,
#    'NewRecovered': 0,
#    'TotalRecovered': 50219,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '7d958e82-eb40-4a6c-b8cf-79b850b3cb2e',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 108629,
#    'NewDeaths': 0,
#    'TotalDeaths': 2909,
#    'NewRecovered': 0,
#    'TotalRecovered': 74330,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '1d3f7734-7866-46fa-9196-c3527312e7bf',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10172,
#    'NewDeaths': 0,
#    'TotalDeaths': 104,
#    'NewRecovered': 0,
#    'TotalRecovered': 9444,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '229d2647-27e8-42ea-8e6f-cac96260e5d3',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20030,
#    'NewDeaths': 0,
#    'TotalDeaths': 474,
#    'NewRecovered': 0,
#    'TotalRecovered': 18431,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b236d0f1-d136-4a1c-a052-3a089bc592a4',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 277,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9edabf02-8f6b-4f67-95e7-cabb62b9dd01',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1970009,
#    'NewDeaths': 0,
#    'TotalDeaths': 48985,
#    'NewRecovered': 0,
#    'TotalRecovered': 1763762,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3532a81a-9daa-4dbc-bf9e-c4eef383c85c',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 167726,
#    'NewDeaths': 0,
#    'TotalDeaths': 3109,
#    'NewRecovered': 0,
#    'TotalRecovered': 159350,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '7225e740-d564-45ce-a708-44fa24605988',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 6,
#    'TotalConfirmed': 28848,
#    'NewDeaths': 0,
#    'TotalDeaths': 909,
#    'NewRecovered': 3,
#    'TotalRecovered': 26083,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2b87f8c1-62d9-4169-b004-5d608bf1b743',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 421189,
#    'NewDeaths': 0,
#    'TotalDeaths': 7973,
#    'NewRecovered': 0,
#    'TotalRecovered': 399329,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '0684b651-c1c7-46cd-a5ae-be9221812982',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 230907,
#    'NewDeaths': 0,
#    'TotalDeaths': 3153,
#    'NewRecovered': 0,
#    'TotalRecovered': 224760,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8bd6e694-6c0d-4a44-ab5f-b93937171130',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8256,
#    'NewDeaths': 0,
#    'TotalDeaths': 176,
#    'NewRecovered': 0,
#    'TotalRecovered': 6819,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '817bdd04-2010-4e2f-85de-4c56c9188e88',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 106198,
#    'NewDeaths': 0,
#    'TotalDeaths': 377,
#    'NewRecovered': 0,
#    'TotalRecovered': 100363,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a926dac1-10f0-4ac2-92ea-c77ae01b4231',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 537465,
#    'NewDeaths': 0,
#    'TotalDeaths': 8182,
#    'NewRecovered': 0,
#    'TotalRecovered': 482424,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3b92f960-1336-4cac-b1d5-289d33fffb20',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1656,
#    'NewDeaths': 0,
#    'TotalDeaths': 17,
#    'NewRecovered': 0,
#    'TotalRecovered': 1289,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b6f796ef-9f2f-4c7b-812a-3df4a774c46f',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 255172,
#    'NewDeaths': 0,
#    'TotalDeaths': 1764,
#    'NewRecovered': 0,
#    'TotalRecovered': 243144,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '284d8928-9d88-4e31-ba53-bc3d05000bd6',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 2585,
#    'TotalConfirmed': 721432,
#    'NewDeaths': 35,
#    'TotalDeaths': 21295,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '20d8b06e-1a0a-4a82-bcba-99201d338fba',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12013,
#    'NewDeaths': 0,
#    'TotalDeaths': 306,
#    'NewRecovered': 0,
#    'TotalRecovered': 11468,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '05e0e182-fb8d-4b38-8ace-62043b2ba1c3',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4193,
#    'NewDeaths': 0,
#    'TotalDeaths': 55,
#    'NewRecovered': 0,
#    'TotalRecovered': 3563,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a469f80c-f2e6-49d9-a87d-410f8b8859f8',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 861,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 852,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2f8c8f31-3a16-4ad8-8072-f8075003f2b4',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 225910,
#    'NewDeaths': 0,
#    'TotalDeaths': 10687,
#    'NewRecovered': 0,
#    'TotalRecovered': 166446,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '42b8905f-aead-471d-852a-64720dca5319',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 123434,
#    'NewDeaths': 0,
#    'TotalDeaths': 4775,
#    'NewRecovered': 0,
#    'TotalRecovered': 97128,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'c33eeebd-19ec-4266-a286-edb663335499',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23503,
#    'NewDeaths': 0,
#    'TotalDeaths': 163,
#    'NewRecovered': 0,
#    'TotalRecovered': 19574,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'de7bc1d1-1841-4fd2-b3c7-a4221f8889c2',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 50872,
#    'TotalConfirmed': 9447165,
#    'NewDeaths': 1239,
#    'TotalDeaths': 230034,
#    'NewRecovered': 29951,
#    'TotalRecovered': 8396148,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '493d1de8-b565-4a97-8772-68c83f69732d',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 180,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 172,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '6e90285b-70bf-4d97-959a-1a07c1a18a73',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 223059,
#    'NewDeaths': 0,
#    'TotalDeaths': 9302,
#    'NewRecovered': 0,
#    'TotalRecovered': 193030,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '75c6fdff-b10a-4887-894e-9c15c39f1981',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11143,
#    'NewDeaths': 0,
#    'TotalDeaths': 132,
#    'NewRecovered': 0,
#    'TotalRecovered': 9941,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'c1978f76-15c5-42cb-99e0-a9e4fa5e414c',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1698,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 773,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'e14c918e-1d9e-4773-b238-f43fbd2c6d65',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 472,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 453,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '1d7754a3-82ab-4865-bb9d-a493b911e922',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 30313,
#    'NewDeaths': 0,
#    'TotalDeaths': 474,
#    'NewRecovered': 0,
#    'TotalRecovered': 28045,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '57868735-c878-4926-b4bc-38fffdd66a3e',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 3740,
#    'TotalConfirmed': 676436,
#    'NewDeaths': 112,
#    'TotalDeaths': 18913,
#    'NewRecovered': 0,
#    'TotalRecovered': 729768,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a23d693c-cf4b-4ea4-bfb4-0e36c8746513',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14306,
#    'NewDeaths': 0,
#    'TotalDeaths': 135,
#    'NewRecovered': 0,
#    'TotalRecovered': 13622,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '415c2925-5179-4da9-8ab5-b1385a6af81c',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4989,
#    'NewDeaths': 0,
#    'TotalDeaths': 63,
#    'NewRecovered': 0,
#    'TotalRecovered': 4885,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9241333a-267d-44ac-ae55-229fee36e43c',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3450,
#    'NewDeaths': 0,
#    'TotalDeaths': 124,
#    'NewRecovered': 0,
#    'TotalRecovered': 2810,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '7cb0e16a-2f60-40b5-bf74-02117780cf44',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 3782,
#    'TotalConfirmed': 744019,
#    'NewDeaths': 77,
#    'TotalDeaths': 18808,
#    'NewRecovered': 3067,
#    'TotalRecovered': 701315,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '48014dc6-74dd-4397-99be-7abe94c559f5',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 50,
#    'TotalConfirmed': 100318,
#    'NewDeaths': 0,
#    'TotalDeaths': 4822,
#    'NewRecovered': 147,
#    'TotalRecovered': 93606,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2b3a4cb2-4dc5-4f90-b122-8ed2d67ce78a',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 7248,
#    'TotalConfirmed': 2142660,
#    'NewDeaths': 272,
#    'TotalDeaths': 55403,
#    'NewRecovered': 9806,
#    'TotalRecovered': 2010941,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '50442cd4-32a7-435e-a6b3-89640943b3e4',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3001,
#    'NewDeaths': 0,
#    'TotalDeaths': 105,
#    'NewRecovered': 0,
#    'TotalRecovered': 2246,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'e97bc2a3-09a9-43d8-a998-0d161bf8f5eb',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8060,
#    'NewDeaths': 0,
#    'TotalDeaths': 122,
#    'NewRecovered': 0,
#    'TotalRecovered': 5846,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'c7300566-a4b1-4947-ac7d-c176e14e616e',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23371,
#    'NewDeaths': 0,
#    'TotalDeaths': 678,
#    'NewRecovered': 0,
#    'TotalRecovered': 15085,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'da91ea48-25e7-484a-aec3-960491d7c8ae',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 196438,
#    'NewDeaths': 0,
#    'TotalDeaths': 2672,
#    'NewRecovered': 0,
#    'TotalRecovered': 156181,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ae1f5e4d-2965-488f-a15e-a7adb8b66b08',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 234702,
#    'NewDeaths': 0,
#    'TotalDeaths': 5122,
#    'NewRecovered': 0,
#    'TotalRecovered': 226625,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9a86c746-a430-4cff-bb93-dcc82aa7109d',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 31190,
#    'NewDeaths': 0,
#    'TotalDeaths': 229,
#    'NewRecovered': 0,
#    'TotalRecovered': 25364,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '12b37d5d-af56-477d-a5d1-4569c45ce8e8',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 31512,
#    'NewDeaths': 0,
#    'TotalDeaths': 210,
#    'NewRecovered': 0,
#    'TotalRecovered': 2057,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'c9aa96cf-300e-4b25-a989-5681dcd35980',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1021477,
#    'NewDeaths': 0,
#    'TotalDeaths': 16976,
#    'NewRecovered': 0,
#    'TotalRecovered': 909305,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '68ff1a2c-63c1-45ee-bde2-b41feb1a2aec',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29295,
#    'NewDeaths': 0,
#    'TotalDeaths': 160,
#    'NewRecovered': 0,
#    'TotalRecovered': 27265,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3101bab9-3d9c-41e7-ae4d-44918e92429c',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 201458,
#    'NewDeaths': 0,
#    'TotalDeaths': 2202,
#    'NewRecovered': 0,
#    'TotalRecovered': 192081,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '6d1abd05-445d-4237-ae2f-2dd1c260380c',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5941,
#    'NewDeaths': 0,
#    'TotalDeaths': 63,
#    'NewRecovered': 0,
#    'TotalRecovered': 5849,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2eca595b-50fa-4ccd-bf2b-ba23f041b33e',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 121,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 110,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '570cfc66-c3e1-41fc-91e9-f976454a5fa8',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 220426,
#    'NewDeaths': 0,
#    'TotalDeaths': 2773,
#    'NewRecovered': 0,
#    'TotalRecovered': 164033,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b9b226d2-c7e4-4b6c-aa92-06892250b25e',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 255412,
#    'NewDeaths': 0,
#    'TotalDeaths': 14982,
#    'NewRecovered': 0,
#    'TotalRecovered': 209814,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8435571d-cd4d-4bbd-b102-24b6316f5f06',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 168597,
#    'NewDeaths': 0,
#    'TotalDeaths': 9560,
#    'NewRecovered': 0,
#    'TotalRecovered': 131632,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'e119335a-d224-4d3b-9e00-a2d8ee5f03ba',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 56025,
#    'NewDeaths': 0,
#    'TotalDeaths': 1662,
#    'NewRecovered': 0,
#    'TotalRecovered': 50189,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '147f77ad-14b3-4d38-ad2f-6c06bc9390f3',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5578,
#    'NewDeaths': 0,
#    'TotalDeaths': 86,
#    'NewRecovered': 0,
#    'TotalRecovered': 5358,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3c077dd9-f03f-4024-a4e3-ffe185aefec1',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2326,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 1719,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'fd6e248a-a987-40cf-b032-fdb06986e16c',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 46925,
#    'NewDeaths': 0,
#    'TotalDeaths': 447,
#    'NewRecovered': 0,
#    'TotalRecovered': 36881,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '0b6c2446-0eb6-4534-a5b4-1c0d69515c0e',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 140883,
#    'NewDeaths': 0,
#    'TotalDeaths': 2136,
#    'NewRecovered': 0,
#    'TotalRecovered': 125241,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ec434f20-77e4-41fb-b064-7845a1d097d7',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 56,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 53,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ee9e0742-fc1c-476d-b5f9-1465cc2dc26a',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 46894,
#    'NewDeaths': 0,
#    'TotalDeaths': 688,
#    'NewRecovered': 0,
#    'TotalRecovered': 31000,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b59d175d-6d11-4896-a283-d4aecb3380e8',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3355678,
#    'NewDeaths': 0,
#    'TotalDeaths': 78749,
#    'NewRecovered': 0,
#    'TotalRecovered': 237755,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '46598f6d-2690-48bb-841f-53e4164fdef8',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11457,
#    'NewDeaths': 0,
#    'TotalDeaths': 71,
#    'NewRecovered': 0,
#    'TotalRecovered': 10797,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '894e12d6-ea67-438b-8a31-e39aba6f132e',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4184,
#    'NewDeaths': 0,
#    'TotalDeaths': 132,
#    'NewRecovered': 0,
#    'TotalRecovered': 3876,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8a31ca97-6040-4beb-be07-0cfdf2d50d83',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 261018,
#    'NewDeaths': 0,
#    'TotalDeaths': 3258,
#    'NewRecovered': 0,
#    'TotalRecovered': 252246,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2ff9b562-6d9f-49bd-8f0d-b32c867d908a',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 10835,
#    'TotalConfirmed': 2276371,
#    'NewDeaths': 690,
#    'TotalDeaths': 61324,
#    'NewRecovered': 12865,
#    'TotalRecovered': 2033168,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '734179bc-8f31-4a5c-abfe-fd65cc7f131e',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 70046,
#    'NewDeaths': 0,
#    'TotalDeaths': 449,
#    'NewRecovered': 0,
#    'TotalRecovered': 63502,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8d769d9e-3206-4389-bb31-739f4dc88137',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 162107,
#    'NewDeaths': 0,
#    'TotalDeaths': 5922,
#    'NewRecovered': 0,
#    'TotalRecovered': 93764,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '79502305-6ae5-4724-beb8-cb27bdd49132',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 148,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 146,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '61bdc053-1db5-457d-b8e9-4a2e918a24e7',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 162295,
#    'NewDeaths': 0,
#    'TotalDeaths': 5816,
#    'NewRecovered': 0,
#    'TotalRecovered': 148133,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b36a2fc8-75c0-46cc-8011-427a95af7763',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14629,
#    'NewDeaths': 0,
#    'TotalDeaths': 84,
#    'NewRecovered': 0,
#    'TotalRecovered': 14301,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'be4866e2-9c46-4904-8f67-595cd3bf30dd',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2752,
#    'NewDeaths': 0,
#    'TotalDeaths': 46,
#    'NewRecovered': 0,
#    'TotalRecovered': 2427,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'c8edca36-cb4c-4a10-b6e4-cb310ee529da',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7887,
#    'NewDeaths': 0,
#    'TotalDeaths': 179,
#    'NewRecovered': 0,
#    'TotalRecovered': 6901,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '4dd5503c-0e3d-4e26-9eed-9ea08bdccb53',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11692,
#    'NewDeaths': 0,
#    'TotalDeaths': 245,
#    'NewRecovered': 0,
#    'TotalRecovered': 9137,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'f990ca85-c1b2-46eb-b2a0-6939d3f1153b',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 15,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '778b54ad-521e-4c48-a59e-d2b556c960c3',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 153253,
#    'NewDeaths': 0,
#    'TotalDeaths': 3694,
#    'NewRecovered': 0,
#    'TotalRecovered': 61587,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8acb79e6-74a8-4faf-b137-77c3c5dcb21f',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 373564,
#    'NewDeaths': 0,
#    'TotalDeaths': 12930,
#    'NewRecovered': 0,
#    'TotalRecovered': 275764,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'f70560b2-060e-4bed-b2f0-3569af07956a',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6021,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 5959,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'e51b707b-0ff5-4f67-87ea-20c31bcb21eb',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 11713,
#    'TotalConfirmed': 10814304,
#    'NewDeaths': 95,
#    'TotalDeaths': 154918,
#    'NewRecovered': 14488,
#    'TotalRecovered': 10510796,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9fe02c8f-6849-41f3-aa59-1bf8cafe75f5',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1134854,
#    'NewDeaths': 0,
#    'TotalDeaths': 31202,
#    'NewRecovered': 0,
#    'TotalRecovered': 926980,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b69906ef-1010-4720-a1d0-1c2385dba003',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1452380,
#    'NewDeaths': 0,
#    'TotalDeaths': 58336,
#    'NewRecovered': 0,
#    'TotalRecovered': 1241320,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9484ce47-425f-45d9-82c5-a7d111173e2f',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 625756,
#    'NewDeaths': 0,
#    'TotalDeaths': 13103,
#    'NewRecovered': 0,
#    'TotalRecovered': 598147,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8ed2c8fb-788c-4a75-8a7a-a9ae1e80dff1',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 201763,
#    'NewDeaths': 0,
#    'TotalDeaths': 3621,
#    'NewRecovered': 0,
#    'TotalRecovered': 23364,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '47beb4f2-c345-49ff-b27a-9ffd58b143d1',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 680856,
#    'NewDeaths': 0,
#    'TotalDeaths': 5020,
#    'NewRecovered': 0,
#    'TotalRecovered': 590822,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '86fa8df8-155e-4482-a0e2-34af509da26c',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 14213,
#    'TotalConfirmed': 2611659,
#    'NewDeaths': 377,
#    'TotalDeaths': 90618,
#    'NewRecovered': 14995,
#    'TotalRecovered': 2091923,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '30f06c5b-9cf4-4a65-8f57-7020808aa2f2',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16513,
#    'NewDeaths': 0,
#    'TotalDeaths': 357,
#    'NewRecovered': 0,
#    'TotalRecovered': 12174,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '32f44989-a5f2-4ee0-9995-3bdddf602b9a',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 2366,
#    'TotalConfirmed': 401858,
#    'NewDeaths': 106,
#    'TotalDeaths': 6278,
#    'NewRecovered': 5141,
#    'TotalRecovered': 354317,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'def8b14e-f9dc-4d46-a88b-e68fac3c86e4',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 332990,
#    'NewDeaths': 0,
#    'TotalDeaths': 4362,
#    'NewRecovered': 0,
#    'TotalRecovered': 318556,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '5789acc4-06d3-4019-aed0-82f5928f4e88',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 240983,
#    'NewDeaths': 0,
#    'TotalDeaths': 3119,
#    'NewRecovered': 0,
#    'TotalRecovered': 210342,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'f9783a77-0084-4a1c-891b-0ff0678c46cd',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 101534,
#    'NewDeaths': 0,
#    'TotalDeaths': 1776,
#    'NewRecovered': 0,
#    'TotalRecovered': 84268,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'c8965324-1141-4807-beeb-168d3b5048c7',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 80524,
#    'NewDeaths': 0,
#    'TotalDeaths': 1464,
#    'NewRecovered': 0,
#    'TotalRecovered': 70505,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8a776131-c782-41ed-9961-c2a22edc2f04',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 169190,
#    'NewDeaths': 0,
#    'TotalDeaths': 964,
#    'NewRecovered': 0,
#    'TotalRecovered': 160554,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '200ee0e9-3d63-4baf-b272-84fc8e1d3c0f',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 84920,
#    'NewDeaths': 0,
#    'TotalDeaths': 1420,
#    'NewRecovered': 0,
#    'TotalRecovered': 81444,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '1cdc1e0a-3e34-4689-a8fc-3c76920f7f76',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 45,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 41,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'fea5f118-dede-4a45-b050-62c3b19f14de',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 70276,
#    'NewDeaths': 0,
#    'TotalDeaths': 1309,
#    'NewRecovered': 0,
#    'TotalRecovered': 57653,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2fc25a3e-84d5-42e2-b7ea-1a5bb0752ffd',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 315340,
#    'NewDeaths': 0,
#    'TotalDeaths': 3495,
#    'NewRecovered': 0,
#    'TotalRecovered': 194430,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b1dcd662-e490-4e28-9854-59f71a5a440d',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9216,
#    'NewDeaths': 0,
#    'TotalDeaths': 180,
#    'NewRecovered': 0,
#    'TotalRecovered': 2669,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'f54f9d6a-baf2-4f70-b4e6-226ab9db62c8',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1956,
#    'NewDeaths': 0,
#    'TotalDeaths': 84,
#    'NewRecovered': 0,
#    'TotalRecovered': 1770,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'eb434568-cf49-42a1-a1b6-3b76b2bfcf33',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 122894,
#    'NewDeaths': 0,
#    'TotalDeaths': 1936,
#    'NewRecovered': 0,
#    'TotalRecovered': 103312,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ff2d1f3a-a4ba-41ab-b86a-7f9834022f6b',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2518,
#    'NewDeaths': 0,
#    'TotalDeaths': 52,
#    'NewRecovered': 0,
#    'TotalRecovered': 2424,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '67f13677-ab52-417d-816a-43a644ebb5f1',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 185601,
#    'NewDeaths': 0,
#    'TotalDeaths': 2908,
#    'NewRecovered': 0,
#    'TotalRecovered': 135406,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b95b48ad-2f92-4a9e-bf57-a21ecf3ce8d8',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 51512,
#    'NewDeaths': 0,
#    'TotalDeaths': 590,
#    'NewRecovered': 0,
#    'TotalRecovered': 48421,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '83c463e0-99fe-4f33-a17c-c8baa9569738',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 94196,
#    'NewDeaths': 0,
#    'TotalDeaths': 2908,
#    'NewRecovered': 0,
#    'TotalRecovered': 83634,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'dfbdd9cf-3c4b-4be3-a11e-511ba86f8641',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19065,
#    'NewDeaths': 0,
#    'TotalDeaths': 281,
#    'NewRecovered': 0,
#    'TotalRecovered': 18215,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2ebae272-307a-4808-801a-e48da10d8c09',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 26360,
#    'NewDeaths': 0,
#    'TotalDeaths': 779,
#    'NewRecovered': 0,
#    'TotalRecovered': 10761,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '4ac4e784-71e1-4c89-a568-7e76c64cbd60',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 234874,
#    'NewDeaths': 0,
#    'TotalDeaths': 845,
#    'NewRecovered': 0,
#    'TotalRecovered': 185278,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'dc17335f-f0a1-4b0e-a0da-80a7ff7a36a2',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16547,
#    'NewDeaths': 0,
#    'TotalDeaths': 54,
#    'NewRecovered': 0,
#    'TotalRecovered': 14472,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '6aafb363-fdf2-41ab-be79-d08694ee9662',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8145,
#    'NewDeaths': 0,
#    'TotalDeaths': 336,
#    'NewRecovered': 0,
#    'TotalRecovered': 6037,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '541db109-337f-4f75-ab86-e9643e8841e0',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18442,
#    'NewDeaths': 0,
#    'TotalDeaths': 277,
#    'NewRecovered': 0,
#    'TotalRecovered': 15701,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b99137e5-c87f-487e-a544-28d7944eb170',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '1f61e89a-7fe0-4a2b-b813-07718efe11d9',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16777,
#    'NewDeaths': 0,
#    'TotalDeaths': 425,
#    'NewRecovered': 0,
#    'TotalRecovered': 15946,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '4ca86ac1-6c00-4a64-ab0b-763740e5432c',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 584,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 540,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a73c6bb5-ddfa-48b8-9b65-e7f3b88a24c7',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 26626,
#    'TotalConfirmed': 1912871,
#    'NewDeaths': 3050,
#    'TotalDeaths': 164290,
#    'NewRecovered': 21914,
#    'TotalRecovered': 1472151,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '78e44698-ab13-470a-8ed7-830e0115ce57',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'f7dcb69d-26bb-4f23-8ccb-04cf9e9ada78',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 163400,
#    'NewDeaths': 0,
#    'TotalDeaths': 3515,
#    'NewRecovered': 0,
#    'TotalRecovered': 152552,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'f9b35a13-3387-431e-b445-a84b2c35954a',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1625,
#    'NewDeaths': 0,
#    'TotalDeaths': 19,
#    'NewRecovered': 0,
#    'TotalRecovered': 1350,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3b5211ae-7c5b-44a1-af91-fb2e31fa9897',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1989,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 1449,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9533c88e-2ef4-4221-93bb-906d85ac66ee',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 64168,
#    'NewDeaths': 0,
#    'TotalDeaths': 831,
#    'NewRecovered': 0,
#    'TotalRecovered': 55753,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b396565e-f1da-43b1-a2dc-1c7cf4526b75',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 474379,
#    'NewDeaths': 0,
#    'TotalDeaths': 8368,
#    'NewRecovered': 0,
#    'TotalRecovered': 453302,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '79b78a37-bb87-4ac0-b37d-f1234666631c',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 43184,
#    'NewDeaths': 0,
#    'TotalDeaths': 436,
#    'NewRecovered': 0,
#    'TotalRecovered': 26212,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '4ef042b7-8890-4f5a-b5f8-7aef6a7e9283',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 141304,
#    'NewDeaths': 0,
#    'TotalDeaths': 3168,
#    'NewRecovered': 0,
#    'TotalRecovered': 127229,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3b465104-101c-4102-aba5-429a9259d0d0',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34615,
#    'NewDeaths': 0,
#    'TotalDeaths': 370,
#    'NewRecovered': 0,
#    'TotalRecovered': 33220,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '822a7643-d64c-4f04-85f5-0a1394bd3a13',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 271707,
#    'NewDeaths': 0,
#    'TotalDeaths': 2035,
#    'NewRecovered': 0,
#    'TotalRecovered': 267564,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '16b7ae54-1cb5-468a-81bd-aeb091ebb1b7',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 4321,
#    'TotalConfirmed': 997751,
#    'NewDeaths': 60,
#    'TotalDeaths': 14294,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '0019eb50-8539-4152-91d7-87cc16e3bd8e',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2315,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 0,
#    'TotalRecovered': 2228,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ecb88e57-3e5e-4568-bfd3-64452d4feacf',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6299,
#    'NewDeaths': 0,
#    'TotalDeaths': 170,
#    'NewRecovered': 0,
#    'TotalRecovered': 4225,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '0c2b7be7-d19a-4537-84be-5f0caa4ec75f',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4589,
#    'NewDeaths': 0,
#    'TotalDeaths': 165,
#    'NewRecovered': 0,
#    'TotalRecovered': 3920,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '7a733077-eee6-4bf9-a6c2-e5c561e6dd64',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 137654,
#    'NewDeaths': 0,
#    'TotalDeaths': 1641,
#    'NewRecovered': 0,
#    'TotalRecovered': 111639,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a327bbad-628f-4e86-9d98-dbce1c604df3',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 64483,
#    'NewDeaths': 0,
#    'TotalDeaths': 582,
#    'NewRecovered': 0,
#    'TotalRecovered': 17998,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a1491edf-a699-4202-9507-a7ad95bce88f',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 135041,
#    'NewDeaths': 0,
#    'TotalDeaths': 1532,
#    'NewRecovered': 0,
#    'TotalRecovered': 127266,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '18293a63-f8e9-4d6d-99cf-c5fd67b6ee5c',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 1286,
#    'TotalConfirmed': 553128,
#    'NewDeaths': 28,
#    'TotalDeaths': 11914,
#    'NewRecovered': 1198,
#    'TotalRecovered': 508700,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b80bce0e-e12c-4ac9-a5f1-b52da0b13dd2',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 161559,
#    'NewDeaths': 0,
#    'TotalDeaths': 1867,
#    'NewRecovered': 0,
#    'TotalRecovered': 151690,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a5127d39-64f8-4b1b-97d2-923557cd4ac5',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 325487,
#    'NewDeaths': 0,
#    'TotalDeaths': 5426,
#    'NewRecovered': 0,
#    'TotalRecovered': 287846,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ae0c5f04-542e-4e10-81c7-05d96d8b5003',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 891,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 828,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'd45fe9e0-eb4d-4062-b13c-2139602a8c81',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 136890,
#    'NewDeaths': 0,
#    'TotalDeaths': 2791,
#    'NewRecovered': 0,
#    'TotalRecovered': 112488,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'f043ac43-6119-40a1-b2a4-25ab32d18a68',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 6715,
#    'TotalConfirmed': 1165052,
#    'NewDeaths': 215,
#    'TotalDeaths': 41753,
#    'NewRecovered': 7317,
#    'TotalRecovered': 1076446,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ac77c950-f2a3-4d2e-9c7f-6b167e7c3790',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 533587,
#    'NewDeaths': 0,
#    'TotalDeaths': 11058,
#    'NewRecovered': 0,
#    'TotalRecovered': 488274,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'ac097335-08be-4f08-a8e3-a4c2b6aed140',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1539564,
#    'NewDeaths': 0,
#    'TotalDeaths': 38712,
#    'NewRecovered': 0,
#    'TotalRecovered': 1294687,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b5b1d291-aee8-4318-8633-a765ef526665',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 755774,
#    'NewDeaths': 0,
#    'TotalDeaths': 13740,
#    'NewRecovered': 0,
#    'TotalRecovered': 585276,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b512332e-2443-4b92-a7e3-ef3b738c1f3c',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 153296,
#    'NewDeaths': 0,
#    'TotalDeaths': 250,
#    'NewRecovered': 0,
#    'TotalRecovered': 146627,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9745c281-f460-49b9-88cb-3c665e166570',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 61688,
#    'NewDeaths': 0,
#    'TotalDeaths': 1519,
#    'NewRecovered': 0,
#    'TotalRecovered': 53457,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '98ee6768-92c8-42e5-9b99-ca8a15abca8f',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 740732,
#    'NewDeaths': 0,
#    'TotalDeaths': 18748,
#    'NewRecovered': 0,
#    'TotalRecovered': 686692,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9bb67595-ce63-4157-ac63-3233340b83ec',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 16444,
#    'TotalConfirmed': 3891274,
#    'NewDeaths': 515,
#    'TotalDeaths': 74520,
#    'NewRecovered': 23279,
#    'TotalRecovered': 3375999,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '5aa01228-3578-4b84-abdb-39422bcaff52',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16186,
#    'NewDeaths': 0,
#    'TotalDeaths': 213,
#    'NewRecovered': 0,
#    'TotalRecovered': 11617,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'd5991dbf-9b5c-4614-9e1b-f6b269abcd1f',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 40,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 36,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a8206e47-ba1d-49cd-81b6-9fe278b46365',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1556,
#    'NewDeaths': 0,
#    'TotalDeaths': 18,
#    'NewRecovered': 0,
#    'TotalRecovered': 779,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '1a5ed715-9b54-4614-af9e-26b9d5e3e45f',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1170,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 377,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '2d6b34ad-9ce7-4e4a-b3fb-02453e7f5070',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 2,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '7fe2c6d8-36ea-4892-a60f-06fb05e7d6dc',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3111,
#    'NewDeaths': 0,
#    'TotalDeaths': 68,
#    'NewRecovered': 0,
#    'TotalRecovered': 2774,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '0911ff9e-a8f6-4274-89b6-834421d44351',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1346,
#    'NewDeaths': 0,
#    'TotalDeaths': 18,
#    'NewRecovered': 0,
#    'TotalRecovered': 1060,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b20c7802-655e-4a06-9bf5-7fea9c90cad0',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 369575,
#    'NewDeaths': 0,
#    'TotalDeaths': 6393,
#    'NewRecovered': 0,
#    'TotalRecovered': 360954,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '12f16ac0-96a4-49e3-ab94-8088cd06bb0f',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 28106,
#    'NewDeaths': 0,
#    'TotalDeaths': 666,
#    'NewRecovered': 0,
#    'TotalRecovered': 23073,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '0b543235-20bc-4cb5-a4dd-cedf1e6268fa',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 404668,
#    'NewDeaths': 0,
#    'TotalDeaths': 4099,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '5846982f-0524-4718-8269-8d636fa917b7',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1289,
#    'NewDeaths': 0,
#    'TotalDeaths': 5,
#    'NewRecovered': 0,
#    'TotalRecovered': 1113,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'be410ea4-d143-4c31-8c32-4c8c6110a243',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3759,
#    'NewDeaths': 0,
#    'TotalDeaths': 79,
#    'NewRecovered': 0,
#    'TotalRecovered': 2415,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '7d496819-355f-4267-9d6d-bcfe349b0723',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 59649,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 0,
#    'TotalRecovered': 59373,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '159a0e33-c1bf-46ad-86c4-7c712adae7a8',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 259533,
#    'NewDeaths': 0,
#    'TotalDeaths': 5050,
#    'NewRecovered': 0,
#    'TotalRecovered': 234371,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'e13607ee-6a42-4c8b-9b3a-82220a0bdfcc',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 172299,
#    'NewDeaths': 0,
#    'TotalDeaths': 3595,
#    'NewRecovered': 0,
#    'TotalRecovered': 152290,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8f59c8fe-12b2-4665-a275-a1094d33dcc9',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 10,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '56c751df-2782-490f-b663-b5a367340984',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4814,
#    'NewDeaths': 0,
#    'TotalDeaths': 132,
#    'NewRecovered': 0,
#    'TotalRecovered': 3720,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '446337f1-4192-43fa-9b17-bfe7c55f7630',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1470516,
#    'NewDeaths': 0,
#    'TotalDeaths': 45902,
#    'NewRecovered': 0,
#    'TotalRecovered': 1335618,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '5f74fb56-363b-4085-ba43-db7c66476968',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4355,
#    'NewDeaths': 0,
#    'TotalDeaths': 66,
#    'NewRecovered': 0,
#    'TotalRecovered': 3663,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9ec69aab-29bb-40b4-896b-4624a5495021',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 28565,
#    'TotalConfirmed': 2941990,
#    'NewDeaths': 584,
#    'TotalDeaths': 61386,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'a110954a-bdf7-4cb2-bdb6-5bcaac253530',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 67850,
#    'NewDeaths': 0,
#    'TotalDeaths': 343,
#    'NewRecovered': 0,
#    'TotalRecovered': 61461,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '75e28a26-4af6-43ec-8445-c8f3bd1ba655',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 29634,
#    'NewDeaths': 0,
#    'TotalDeaths': 1831,
#    'NewRecovered': 0,
#    'TotalRecovered': 21794,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '6c90e27d-8887-4133-b1cc-6f6bfeb7cb79',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8619,
#    'NewDeaths': 0,
#    'TotalDeaths': 158,
#    'NewRecovered': 0,
#    'TotalRecovered': 7939,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '1a169915-4391-44dc-ae9d-cf0419b64f3a',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 16137,
#    'NewDeaths': 0,
#    'TotalDeaths': 600,
#    'NewRecovered': 0,
#    'TotalRecovered': 11289,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '17cba387-f5f0-499c-b344-d4531d3639cf',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 3388,
#    'TotalConfirmed': 588062,
#    'NewDeaths': 87,
#    'TotalDeaths': 12115,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '6384a3d4-9314-467f-ae2c-e0bf9ddb05a7',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 531873,
#    'NewDeaths': 0,
#    'TotalDeaths': 9584,
#    'NewRecovered': 0,
#    'TotalRecovered': 317600,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '11595ee5-d5cc-47d7-8bb7-f999d1e9114c',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14338,
#    'NewDeaths': 0,
#    'TotalDeaths': 943,
#    'NewRecovered': 0,
#    'TotalRecovered': 7974,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '5a8f3b19-32b6-4db8-81ca-44c4c2283f8d',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 923,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 841,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '03835150-550f-44a4-ae1d-18ac78616326',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13308,
#    'NewDeaths': 0,
#    'TotalDeaths': 90,
#    'NewRecovered': 0,
#    'TotalRecovered': 13218,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'd571531b-5257-4007-8264-40b4b7f96b47',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 509,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '50c30ecd-58d4-4f29-82bf-36bae2fdbe99',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23134,
#    'NewDeaths': 0,
#    'TotalDeaths': 79,
#    'NewRecovered': 0,
#    'TotalRecovered': 16274,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'b3020d16-e123-4cf8-9984-11d23c1dc6c6',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 80,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 61,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '93f7979b-debc-4a47-aea2-359dce3d86d6',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5356,
#    'NewDeaths': 0,
#    'TotalDeaths': 79,
#    'NewRecovered': 0,
#    'TotalRecovered': 4456,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3ce9b075-8c17-4d4a-985b-687aaaa95a85',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7607,
#    'NewDeaths': 0,
#    'TotalDeaths': 135,
#    'NewRecovered': 0,
#    'TotalRecovered': 7242,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'e12ef5ca-a7e6-4e74-a2ba-c454f75f2855',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 215112,
#    'NewDeaths': 0,
#    'TotalDeaths': 7099,
#    'NewRecovered': 0,
#    'TotalRecovered': 171143,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '56ec1119-688e-47d5-9f9d-2894bc1c40d5',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2516889,
#    'NewDeaths': 0,
#    'TotalDeaths': 26577,
#    'NewRecovered': 0,
#    'TotalRecovered': 2404416,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '6d9ea4b8-c53b-4d17-88f6-a2e5fea90a33',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 39789,
#    'NewDeaths': 0,
#    'TotalDeaths': 327,
#    'NewRecovered': 0,
#    'TotalRecovered': 14349,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'cb064888-5d32-488b-bf9d-98e6f5c11761',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 5167,
#    'TotalConfirmed': 1280501,
#    'NewDeaths': 170,
#    'TotalDeaths': 24599,
#    'NewRecovered': 8488,
#    'TotalRecovered': 1101087,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'e95b8432-78c0-42ec-a735-a9673578f13a',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 320126,
#    'NewDeaths': 0,
#    'TotalDeaths': 902,
#    'NewRecovered': 0,
#    'TotalRecovered': 297040,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '113d8615-2db6-4325-ae21-896e08585ae8',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 19204,
#    'TotalConfirmed': 3922910,
#    'NewDeaths': 1015,
#    'TotalDeaths': 111477,
#    'NewRecovered': 83,
#    'TotalRecovered': 10094,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': 'd7dbbec6-f3d9-485a-87c7-642610e7ae34',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 133558,
#    'TotalConfirmed': 26813772,
#    'NewDeaths': 3674,
#    'TotalDeaths': 459555,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3691104a-c1b5-40b8-8dc8-3dfe51a7fc35',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 44303,
#    'NewDeaths': 0,
#    'TotalDeaths': 478,
#    'NewRecovered': 0,
#    'TotalRecovered': 37967,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '414e36b3-3794-4680-a5cd-93e290599894',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 78989,
#    'NewDeaths': 0,
#    'TotalDeaths': 621,
#    'NewRecovered': 0,
#    'TotalRecovered': 77443,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '1659b90e-7566-43b4-8d3b-2b291a8db1d8',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3079e56b-c254-44b0-a2b4-cfe7f3b16557',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 129231,
#    'NewDeaths': 0,
#    'TotalDeaths': 1223,
#    'NewRecovered': 0,
#    'TotalRecovered': 121094,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '3a6bfe80-49fe-4617-88b8-b2b862dea1d8',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1976,
#    'NewDeaths': 0,
#    'TotalDeaths': 35,
#    'NewRecovered': 0,
#    'TotalRecovered': 1465,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '9b2da16c-ccbc-4109-97e7-6e04d61da137',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2124,
#    'NewDeaths': 0,
#    'TotalDeaths': 615,
#    'NewRecovered': 0,
#    'TotalRecovered': 1427,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '8a5207ab-15a4-402a-b25a-974c3603eb10',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 60427,
#    'NewDeaths': 0,
#    'TotalDeaths': 828,
#    'NewRecovered': 0,
#    'TotalRecovered': 52045,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}},
#   {'ID': '503c337a-063d-4c30-955f-f8ad92e7ba3a',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34331,
#    'NewDeaths': 0,
#    'TotalDeaths': 1303,
#    'NewRecovered': 0,
#    'TotalRecovered': 28145,
#    'Date': '2021-02-06T15:36:47.049Z',
#    'Premium': {}}],
#  'Date': '2021-02-06T15:36:47.049Z'}

# %%
data['Global']
# Out:
# {'NewConfirmed': 352684,
#  'TotalConfirmed': 105251877,
#  'NewDeaths': 12401,
#  'TotalDeaths': 2297413,
#  'NewRecovered': 152742,
#  'TotalRecovered': 58566864,
#  'Date': '2021-02-06T15:36:47.049Z'}

# %%
global_total_confirmed = data['Global']['TotalConfirmed']
global_total_confirmed
# Out:
# 105251877

# %%
global_today_new = data['Global']['NewConfirmed']
global_today_new
# Out:
# 352684

# %%
global_total_deaths = data['Global']['TotalDeaths']
global_total_deaths
# Out:
# 2297413

# %%
global_total_recovered = data['Global']['TotalRecovered']
global_total_recovered
# Out:
# 58566864

# %%
global_update_date = data['Global']['Date']
global_update_date
# Out:
# '2021-02-06T15:36:47.049Z'

# %%
df = pd.json_normalize(data,'Countries').drop(['ID','Date'],axis=1)
df.head(10)
# Out:
#                Country CountryCode                 Slug  NewConfirmed  \
# 0          Afghanistan          AF          afghanistan             0
# 1              Albania          AL              albania             0
# 2              Algeria          DZ              algeria             0
# 3              Andorra          AD              andorra             0
# 4               Angola          AO               angola             0
# 5  Antigua and Barbuda          AG  antigua-and-barbuda             0
# 6            Argentina          AR            argentina             0
# 7              Armenia          AM              armenia             0
# 8            Australia          AU            australia             6
# 9              Austria          AT              austria             0
#
#    TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  TotalRecovered
# 0           55265          0         2407             0           48018
# 1           83082          0         1433             0           50219
# 2          108629          0         2909             0           74330
# 3           10172          0          104             0            9444
# 4           20030          0          474             0           18431
# 5             277          0            7             0             183
# 6         1970009          0        48985             0         1763762
# 7          167726          0         3109             0          159350
# 8           28848          0          909             3           26083
# 9          421189          0         7973             0          399329

# %%
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# <ipython-input-20-853bb7adb0d6> in <module>
#      35
#      36
# ---> 37 altair_geo_analysis(df)
#
# <ipython-input-20-853bb7adb0d6> in altair_geo_analysis(final_df)
#       2     world_source = final_df
#       3
# ----> 4     source = alt.topo_feature(final_df.Country, "countries")
#       5     background = alt.Chart(source).mark_geoshape(fill="white")
#       6
#
# ~/anaconda3/lib/python3.8/site-packages/altair/vegalite/v4/api.py in topo_feature(url, feature, **kwargs)
#    2380         additional keywords passed to TopoDataFormat
#    2381     """
# -> 2382     return core.UrlData(
#    2383         url=url, format=core.TopoDataFormat(type="topojson", feature=feature, **kwargs)
#    2384     )
#
# ~/anaconda3/lib/python3.8/site-packages/altair/vegalite/v4/schema/core.py in __init__(self, url, format, name, **kwds)
#   18829
#   18830     def __init__(self, url=Undefined, format=Undefined, name=Undefined, **kwds):
# > 18831         super(UrlData, self).__init__(url=url, format=format, name=name, **kwds)
#   18832
#   18833
#
# ~/anaconda3/lib/python3.8/site-packages/altair/vegalite/v4/schema/core.py in __init__(self, *args, **kwds)
#    4457
#    4458     def __init__(self, *args, **kwds):
# -> 4459         super(DataSource, self).__init__(*args, **kwds)
#    4460
#    4461
#
# ~/anaconda3/lib/python3.8/site-packages/altair/vegalite/v4/schema/core.py in __init__(self, *args, **kwds)
#    4396
#    4397     def __init__(self, *args, **kwds):
# -> 4398         super(Data, self).__init__(*args, **kwds)
#    4399
#    4400
#
# ~/anaconda3/lib/python3.8/site-packages/altair/utils/schemapi.py in __init__(self, *args, **kwds)
#     174
#     175         if DEBUG_MODE and self._class_is_valid_at_instantiation:
# --> 176             self.to_dict(validate=True)
#     177
#     178     def copy(self, deep=True, ignore=()):
#
# ~/anaconda3/lib/python3.8/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     337                 self.validate(result)
#     338             except jsonschema.ValidationError as err:
# --> 339                 raise SchemaValidationError(self, err)
#     340         return result
#     341
#
# SchemaValidationError: Invalid specification
#
#         altair.vegalite.v4.schema.core.UrlData->url, validating 'type'
#
#         {0: 'Afghanistan', 1: 'Albania', 2: 'Algeria', 3: 'Andorra', 4: 'Angola', 5: 'Antigua and Barbuda', 6: 'Argentina', 7: 'Armenia', 8: 'Australia', 9: 'Austria', 10: 'Azerbaijan', 11: 'Bahamas', 12: 'Bahrain', 13: 'Bangladesh', 14: 'Barbados', 15: 'Belarus', 16: 'Belgium', 17: 'Belize', 18: 'Benin', 19: 'Bhutan', 20: 'Bolivia', 21: 'Bosnia and Herzegovina', 22: 'Botswana', 23: 'Brazil', 24: 'Brunei Darussalam', 25: 'Bulgaria', 26: 'Burkina Faso', 27: 'Burundi', 28: 'Cambodia', 29: 'Cameroon', 30: 'Canada', 31: 'Cape Verde', 32: 'Central African Republic', 33: 'Chad', 34: 'Chile', 35: 'China', 36: 'Colombia', 37: 'Comoros', 38: 'Congo (Brazzaville)', 39: 'Congo (Kinshasa)', 40: 'Costa Rica', 41: 'Croatia', 42: 'Cuba', 43: 'Cyprus', 44: 'Czech Republic', 45: "Côte d'Ivoire", 46: 'Denmark', 47: 'Djibouti', 48: 'Dominica', 49: 'Dominican Republic', 50: 'Ecuador', 51: 'Egypt', 52: 'El Salvador', 53: 'Equatorial Guinea', 54: 'Eritrea', 55: 'Estonia', 56: 'Ethiopia', 57: 'Fiji', 58: 'Finland', 59: 'France', 60: 'Gabon', 61: 'Gambia', 62: 'Georgia', 63: 'Germany', 64: 'Ghana', 65: 'Greece', 66: 'Grenada', 67: 'Guatemala', 68: 'Guinea', 69: 'Guinea-Bissau', 70: 'Guyana', 71: 'Haiti', 72: 'Holy See (Vatican City State)', 73: 'Honduras', 74: 'Hungary', 75: 'Iceland', 76: 'India', 77: 'Indonesia', 78: 'Iran, Islamic Republic of', 79: 'Iraq', 80: 'Ireland', 81: 'Israel', 82: 'Italy', 83: 'Jamaica', 84: 'Japan', 85: 'Jordan', 86: 'Kazakhstan', 87: 'Kenya', 88: 'Korea (South)', 89: 'Kuwait', 90: 'Kyrgyzstan', 91: 'Lao PDR', 92: 'Latvia', 93: 'Lebanon', 94: 'Lesotho', 95: 'Liberia', 96: 'Libya', 97: 'Liechtenstein', 98: 'Lithuania', 99: 'Luxembourg', 100: 'Macedonia, Republic of', 101: 'Madagascar', 102: 'Malawi', 103: 'Malaysia', 104: 'Maldives', 105: 'Mali', 106: 'Malta', 107: 'Marshall Islands', 108: 'Mauritania', 109: 'Mauritius', 110: 'Mexico', 111: 'Micronesia, Federated States of', 112: 'Moldova', 113: 'Monaco', 114: 'Mongolia', 115: 'Montenegro', 116: 'Morocco', 117: 'Mozambique', 118: 'Myanmar', 119: 'Namibia', 120: 'Nepal', 121: 'Netherlands', 122: 'New Zealand', 123: 'Nicaragua', 124: 'Niger', 125: 'Nigeria', 126: 'Norway', 127: 'Oman', 128: 'Pakistan', 129: 'Palestinian Territory', 130: 'Panama', 131: 'Papua New Guinea', 132: 'Paraguay', 133: 'Peru', 134: 'Philippines', 135: 'Poland', 136: 'Portugal', 137: 'Qatar', 138: 'Republic of Kosovo', 139: 'Romania', 140: 'Russian Federation', 141: 'Rwanda', 142: 'Saint Kitts and Nevis', 143: 'Saint Lucia', 144: 'Saint Vincent and Grenadines', 145: 'Samoa', 146: 'San Marino', 147: 'Sao Tome and Principe', 148: 'Saudi Arabia', 149: 'Senegal', 150: 'Serbia', 151: 'Seychelles', 152: 'Sierra Leone', 153: 'Singapore', 154: 'Slovakia', 155: 'Slovenia', 156: 'Solomon Islands', 157: 'Somalia', 158: 'South Africa', 159: 'South Sudan', 160: 'Spain', 161: 'Sri Lanka', 162: 'Sudan', 163: 'Suriname', 164: 'Swaziland', 165: 'Sweden', 166: 'Switzerland', 167: 'Syrian Arab Republic (Syria)', 168: 'Taiwan, Republic of China', 169: 'Tajikistan', 170: 'Tanzania, United Republic of', 171: 'Thailand', 172: 'Timor-Leste', 173: 'Togo', 174: 'Trinidad and Tobago', 175: 'Tunisia', 176: 'Turkey', 177: 'Uganda', 178: 'Ukraine', 179: 'United Arab Emirates', 180: 'United Kingdom', 181: 'United States of America', 182: 'Uruguay', 183: 'Uzbekistan', 184: 'Vanuatu', 185: 'Venezuela (Bolivarian Republic)', 186: 'Viet Nam', 187: 'Yemen', 188: 'Zambia', 189: 'Zimbabwe'} is not of type 'string'
